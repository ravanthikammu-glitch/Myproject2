# %% [markdown]
# <a href="https://colab.research.google.com/github/ravanthikammu-glitch/Myproject2/blob/main/avanthika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-d201563b-e379-4a7b-83f1-c97e290cbc81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d201563b-e379-4a7b-83f1-c97e290cbc81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("dynamic_api_call_sequence_per_malware_100_0_306.csv")
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43876 entries, 0 to 43875
# Columns: 102 entries, hash to malware
# dtypes: int64(101), object(1)
# memory usage: 34.1+ MB

# %%
df.isnull()
# Out:
#         hash    t_0    t_1    t_2    t_3    t_4    t_5    t_6    t_7    t_8  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 43871  False  False  False  False  False  False  False  False  False  False
# 43872  False  False  False  False  False  False  False  False  False  False
# 43873  False  False  False  False  False  False  False  False  False  False
# 43874  False  False  False  False  False  False  False  False  False  False
# 43875  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# hash       0
# t_0        0
# t_1        0
# t_2        0
# t_3        0
#           ..
# t_96       0
# t_97       0
# t_98       0
# t_99       0
# malware    0
# Length: 102, dtype: int64

# %%
df.describe()
# Out:
#                 t_0           t_1           t_2           t_3           t_4  \
# count  43876.000000  43876.000000  43876.000000  43876.000000  43876.000000
# mean     142.830226    211.477414    148.217294    189.045674    187.514746
# std       75.599441     60.082481     47.667868     68.119087     71.196556
# min        2.000000      2.000000      2.000000      2.000000      0.000000
# 25%       82.000000    172.000000    117.000000    117.000000    117.000000
# 50%       82.000000    240.000000    158.000000    215.000000    172.000000
# 75%      215.000000    240.000000    172.000000    240.000000    274.000000
# max      306.000000    306.000000    306.000000    306.000000    306.000000
#
#                 t_5           t_6           t_7           t_8           t_9  \
# count  43876.000000  43876.000000  43876.000000  43876.000000  43876.000000
# mean     174.190218    170.290022    199.070015    142.659016    167.358921
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43871    False
# 43872    False
# 43873    False
# 43874    False
# 43875    False
# Length: 43876, dtype: bool

# %%
df.dropna()
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 3      72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 43872  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 43873  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 43874  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 43875  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna("no data")
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 3      72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 43872  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 43873  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 43874  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 43875  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 3      72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 43872  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 43873  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 43874  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 43875  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
# ...

# %%
df.isnull().sum()
# Out:
# hash       0
# t_0        0
# t_1        0
# t_2        0
# t_3        0
#           ..
# t_96       0
# t_97       0
# t_98       0
# t_99       0
# malware    0
# Length: 102, dtype: int64

# %%
df
# Out:
#                                    hash  t_0  t_1  t_2  t_3  t_4  t_5  t_6  \
# 0      071e8c3f8922e186e57548cd4c703a5d  112  274  158  215  274  158  215
# 1      33f8e6d08a6aae939f25a8e0d63dd523   82  208  187  208  172  117  172
# 2      b68abd064e975e1c6d5f25e748663076   16  110  240  117  240  117  240
# 3      72049be7bd30ea61297ea624ae198067   82  208  187  208  172  117  172
# 4      c9b3700a77facf29172f32df6bc77f48   82  240  117  240  117  240  117
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 43871  e3d6d58faa040f0f9742c9d0eaf58be4   82  240  117  240  117  240  117
# 43872  9b917bab7f32188ae40c744f2be9aaf8   82  240  117  240  117  240  117
# 43873  35a18ee05f75f04912018d9f462cb990   82  240  117  240  117  240  117
# 43874  654139d715abcf7ecdddbef5a84f224b   82  240  117  240  117  240  117
# 43875  078c9d4e7be4819a06974c6f292a4857  112  274  158  215  274  158  215
#
# ...

# %%
df.to_csv('FINAL.csv', index=False)

# %%
files.download('FINAL.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['t_0'], df['t_99'], color='red')
plt.title('Scatter plot')
plt.xlabel('t_0')
plt.ylabel('t_99')
plt.show()

# %%
plt.bar(df['t_0'], df['t_99'], color='red')
plt.title('Bar plot')
plt.xlabel('t_0')
plt.ylabel('t_99')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['t_0'], df['t_99'], color='red')
plt.title('Line plot')
plt.xlabel('t_0')
plt.ylabel('t_99')
plt.show()
